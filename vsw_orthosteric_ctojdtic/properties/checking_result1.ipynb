# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("final_props_filters_bbb.txt")
df
# Out:
#                                                    SMILES             NAMES  \
# 0       NC(=O)c1ccc[n+](c1)[C@@H]2O[C@@H]([C@H](O)[C@H...  ZINC000238950259
# 1       O[P+]1(O)O[P+](O)(O)O[P+](O)(O)O[P+](O)(O)O[P+...  ZINC000257373260
# 2       NC(=O)c1ccc[n+](c1)[C@@H]2O[C@@H]([C@@H](O)[C@...  ZINC000238950261
# 3       Nc1ncnc(c12)n(cn2)[C@@H]3O[C@@H](C[C@H]3O)CO[P...  ZINC000013540909
# 4       O=c1ccn(c(=O)[nH]1)[C@@H]2O[C@H]([C@@H](O)[C@H...  ZINC000003875256
# ...                                                   ...               ...
# 136135  COc1ccc(cc1)N[C@H]2CCC[N@H+](C2)Cc3cc(OC)c(OC)...  ZINC000011937649
# 136136  COc1ccc(cc1)N[C@H]2CCC[N@H+](C2)Cc3cc(OC)c(OC)...  ZINC000011937649
# 136137                    COc1ccccc1OCCCn(cn2)c(c23)cccc3  ZINC000002868223
# 136138    COc1c(Cl)cc(cc1OC)C[NH2+]CCc(c[nH]2)c(c23)cccc3  ZINC000004488639
# 136139  Fc1ccccc1CNC(=O)CC[N@H+](C2)C[C@H]([C@H]23)[C@...  ZINC000072171728
#
#          WLogP   TPSAB      LogS         FILTERS  BBB
# ...

# %%
num_of_molecules = df.shape[0]
num_of_molecules
# Out:
# 136140

# %%
df1 = df[df["FILTERS"]=="1"]
df1
# Out:
#                                                    SMILES             NAMES  \
# 17      [NH3+]C[C@@H]1O[C@@H]([C@H]([NH3+])C[C@@H]1O)O...  ZINC000008101193
# 18      [NH3+]C[C@H]1O[C@@H]([C@@H]([NH3+])C[C@@H]1O)O...  ZINC000008551165
# 25      [NH3+]C[C@@H]1O[C@@H]([C@H]([NH3+])C[C@H]1O)O[...  ZINC000076945729
# 30      C[NH2+][C@@H]([C@@]1(C)O)[C@@H](O)[C@@H](OC1)O...  ZINC000070672626
# 31      [NH3+]C[C@@H]1O[C@H]([C@@H]([NH3+])C[C@@H]1O)O...  ZINC000008551162
# ...                                                   ...               ...
# 136133  Fc1ccccc1-n(nc2)c(c23)CCC[C@@H]3[NH2+]Cc(c4)oc...  ZINC000020995759
# 136134  C1CCCC1CCC(=O)N(CC[NH+](C)C)Cc2ccc(cc2)OS(=O)(...  ZINC000034921482
# 136137                    COc1ccccc1OCCCn(cn2)c(c23)cccc3  ZINC000002868223
# 136138    COc1c(Cl)cc(cc1OC)C[NH2+]CCc(c[nH]2)c(c23)cccc3  ZINC000004488639
# 136139  Fc1ccccc1CNC(=O)CC[N@H+](C2)C[C@H]([C@H]23)[C@...  ZINC000072171728
#
#          WLogP   TPSAB      LogS FILTERS  BBB
# ...

# %%
df2 = df1[df1["BBB"]==1]
df2
# Out:
#                                                    SMILES             NAMES  \
# 334               c1cc[nH+]c(c12)NC([O-])=CC(=N2)c3ccccc3  ZINC000015828584
# 512     COc1ccc(cc1OC)C[N@H+](CCC[NH3+])CC[C@@]2(c3ccc...  ZINC000015162196
# 608     n1ccccc1CCC(=O)N(CCC[NH+](C)C)C[C@H]2CC[N@@H+]...  ZINC000012308844
# 771                 OCC(C1)CN1C(=O)Nc2cccc(c2)CCCc3ccccc3  ZINC000192211539
# 834           o1cccc1C[C@H](C)NC(=O)c2ccccc2OCc3ccc(F)cc3  ZINC000040074723
# ...                                                   ...               ...
# 136133  Fc1ccccc1-n(nc2)c(c23)CCC[C@@H]3[NH2+]Cc(c4)oc...  ZINC000020995759
# 136134  C1CCCC1CCC(=O)N(CC[NH+](C)C)Cc2ccc(cc2)OS(=O)(...  ZINC000034921482
# 136137                    COc1ccccc1OCCCn(cn2)c(c23)cccc3  ZINC000002868223
# 136138    COc1c(Cl)cc(cc1OC)C[NH2+]CCc(c[nH]2)c(c23)cccc3  ZINC000004488639
# 136139  Fc1ccccc1CNC(=O)CC[N@H+](C2)C[C@H]([C@H]23)[C@...  ZINC000072171728
#
#          WLogP  TPSAB      LogS FILTERS  BBB
# ...

# %%
df3 = df2[(df2["LogS"]>=-5.0) & (df2["LogS"]<=-1.0)]
df3
# Out:
#                                                    SMILES             NAMES  \
# 334               c1cc[nH+]c(c12)NC([O-])=CC(=N2)c3ccccc3  ZINC000015828584
# 512     COc1ccc(cc1OC)C[N@H+](CCC[NH3+])CC[C@@]2(c3ccc...  ZINC000015162196
# 608     n1ccccc1CCC(=O)N(CCC[NH+](C)C)C[C@H]2CC[N@@H+]...  ZINC000012308844
# 771                 OCC(C1)CN1C(=O)Nc2cccc(c2)CCCc3ccccc3  ZINC000192211539
# 886         C[NH2+]CCC[NH2+]Cc1ccc(c(c1)OC)OCc2ccc(Cl)cc2  ZINC000008377044
# ...                                                   ...               ...
# 136128  Cn1cc[nH+]c1[C@@H](c2ccc(F)cc2)NC(=O)CNC(=O)c3...  ZINC000012575505
# 136131     C1CSCC[NH+]1C[C@@H](O)COc2ccccc2CNCc3ccc(F)cc3  ZINC000014964630
# 136137                    COc1ccccc1OCCCn(cn2)c(c23)cccc3  ZINC000002868223
# 136138    COc1c(Cl)cc(cc1OC)C[NH2+]CCc(c[nH]2)c(c23)cccc3  ZINC000004488639
# 136139  Fc1ccccc1CNC(=O)CC[N@H+](C2)C[C@H]([C@H]23)[C@...  ZINC000072171728
#
#          WLogP  TPSAB      LogS FILTERS  BBB
# ...

# %%
df3.to_csv("mols_to_clusterize.csv", index=False)
